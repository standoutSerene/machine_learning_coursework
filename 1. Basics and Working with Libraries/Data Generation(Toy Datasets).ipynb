# %%
# scikit learn

# %%
# testing and learning purpose

# %%
# classification, regression, clustering, MNIST etc.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_digits

# %%
mnist = load_digits()

# %%
print(type(mnist))
# Out:
# <class 'sklearn.utils.Bunch'>

# %%
X = mnist.data
Y = mnist.target

# %%
print(X.shape)
# Out:
# (1797, 64)

# %%
print(Y.shape)
# Out:
# (1797,)

# %%
plt.imshow(X[3].reshape((8,8)), cmap = 'gray')
plt.show()

print(Y[3])
# Out:
# 3

# %%
# image of 3

# %%
from sklearn.datasets import load_boston, make_classification, make_regression, make_blobs

# %%
boston = load_boston()

# %%
XB = boston.data
YB = boston.target

# %%
print(XB.shape)
print(YB.shape)
# Out:
# (506, 13)
# (506,)

# %%
# boston is a house prices dataset

# %%
X,Y = make_classification(n_samples = 100, n_features = 2, n_informative = 2, n_redundant = 0,n_classes = 2)

# %%
plt.scatter(X[:,0],X[:,1],c = Y,edgeColor = 'k')

# %%
 X1,Y1 = make_classification(n_samples = 100, n_features = 2, n_informative = 2,n_redundant = 0, n_classes = 3,n_clusters_per_class = 1)

# %%
plt.scatter(X1[:,0],X1[:,1],c = Y1, edgeColor = 'k')

# %%
plt.figure(0,figsize=(8,8)) # doing this since title was not readable

X,Y = make_classification(n_samples = 100, n_features = 2, n_informative = 2, n_redundant = 0, n_classes = 2)
plt.subplot(221)
plt.scatter(X[:,0],X[:,1], c = Y, edgeColor = 'k')

X1,Y1 = make_classification(n_samples = 100,n_features = 2, n_informative = 2, n_redundant = 0, n_classes =3, n_clusters_per_class = 1)
plt.subplot(222)
plt.scatter(X1[:,0],X1[:,1],c = Y1, edgeColor = 'k')


X2,Y2 = make_blobs(n_features = 2, centers = 3)   # number of points by default is 100
plt.subplot(223)
plt.title("Blobs")
plt.scatter(X2[:,0],X2[:,1], c = Y2, edgeColor = 'k')


plt.subplot(224)
X3,Y3 = make_regression(n_features = 1, n_samples = 200,bias= 4, noise = 15)
plt.title("Regression")
plt.scatter(X3, Y3, color ='orange', edgeColor = 'k')
# we also need to define the intercept of the line(on y-axis), this is also called the bias
# recall the student example of regression of number of hours studied and marks in exam

plt.plot()
# Out:
# []
